# %% [markdown]
# from ultralytics import YOLO

# %%
from ultralytics import YOLO
model = YOLO("yolo11n.pt")
train_results = model.train(
    data = "D:\\OLD_DATA\\Users\\DELL\\Downloads\\License Plate Recognition.v11i.yolov11\\data.yaml",
    epochs=5,
    imgsz=640,
    device="cpu"
)
# Out:
# Ultralytics 8.3.174  Python-3.13.2 torch-2.7.1+cpu CPU (Intel Core(TM) i3-1005G1 1.20GHz)
# ...

# %%
from ultralytics import YOLO
model = YOLO("runs\\detect\\train3\\weights\\best.pt")
results = model(r"D:\OLD_DATA\Users\DELL\Downloads\License Plate Recognition.v11i.yolov11\train\images\xemay591_jpg.rf.04550a3db77f8759daa9354a261a6bd6.jpg")
results[0].show()
# Out:
# image 1/1 D:\OLD_DATA\Users\DELL\Downloads\License Plate Recognition.v11i.yolov11\train\images\xemay591_jpg.rf.04550a3db77f8759daa9354a261a6bd6.jpg: 416x640 1 License_Plate, 218.4ms
# Speed: 5.8ms preprocess, 218.4ms inference, 2.8ms postprocess per image at shape (1, 3, 416, 640)

# %%
from ultralytics import YOLO
model = YOLO("runs\\detect\\train3\\weights\\best.pt")
results = model(r"D:\OLD_DATA\Users\DELL\Downloads\pratik.jpeg")
results[0].show()
# Out:
# image 1/1 D:\OLD_DATA\Users\DELL\Downloads\pratik.jpeg: 640x288 1 License_Plate, 190.4ms
# Speed: 5.4ms preprocess, 190.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 288)
